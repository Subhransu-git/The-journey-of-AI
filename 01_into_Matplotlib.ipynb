# %% [markdown]
# # What is python matplotlib?
# - Matplotlib is a 2D and 3D graph plotting python library. It also supports to create animations and images. This is an advanced part of python matplotlib.

# %%
it is  a graphical representation of info and data.visual elements like graphs and maps ,data tools provide an 
accessible way to see  and understand trends,outliers and patterns in data.
it was introduced by john hunter in 2002.

# %% [markdown]
# # Use of Matplotlib
# 1.Data analysis in Python
# 2.Machine learning projects
# 3.Research and scientific work
# 4.Custom visualizations
# 5.Automation of reports

# %% [markdown]
# # When to Use Each Tool
#
# Use Matplotlib when:
#
# Working in Python
# Learning data science
# Building ML models
# Creating custom graphs
# Automating reports
#
# Use Power BI when:
#
# Creating business dashboards
# Sharing reports with managers
# Connecting multiple business data sources

# %% [markdown]
# # Using python matplotlib, you can draw a different graph like
# - - line graph
# - - Histogram
# - - Bar Chart
# - - Pie Chart
# - - Scatterplots
# - - Area Plot
# - - Error charts
# - - Power Spectra

# %% [markdown]
# Histogram

# %% [markdown]
# ![histogram-example-1.png](attachment:histogram-example-1.png)

# %% [markdown]
# Bar Chart

# %% [markdown]
# ![grouped-bar-example-1.png](attachment:grouped-bar-example-1.png)

# %% [markdown]
# Pie Chart

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)

# %% [markdown]
# Scatterplots

# %% [markdown]
# ![download%20%282%29.png](attachment:download%20%282%29.png)

# %% [markdown]
# Area Plot

# %% [markdown]
# ![download%20%283%29.png](attachment:download%20%283%29.png)

# %% [markdown]
# Error charts

# %% [markdown]
# ![download%20%284%29.png](attachment:download%20%284%29.png)

# %% [markdown]
# Power Spectra

# %% [markdown]
# ![MG8dz.jpg](attachment:MG8dz.jpg)

# %% [markdown]
# # Dependency
# - numpy
# - pandas

# %% [markdown]
# # Installation of matplotlib
# pip install matplotlib

# %%
pip install numpy
pip install pandas

import pandas as pd
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
